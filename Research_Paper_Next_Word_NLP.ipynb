# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dblp-v10.csv')

# %%
df
# Out:
#                                                  abstract  \
# 0       In this paper, a robust 3D triangular mesh wat...
# 1       We studied an autoassociative neural network w...
# 2       It is well-known that Sturmian sequences are t...
# 3       One of the fundamental challenges of recognizi...
# 4       This paper generalizes previous optimal upper ...
# ...                                                   ...
# 999995  In MANETs, exchange of data is carried out wit...
# 999996  This paper presents a micro-power photovoltaic...
# 999997  In this work, a distillation system is designe...
# 999998                                                NaN
# 999999  The uninorms with continuous underlying t-norm...
#
#                                                   authors  n_citation  \
# 0                  ['S. Ben Jabra', 'Ezzeddine Zagrouba']          50
# 1       ['Joaquín J. Torres', 'Jesús M. Cortés', 'Joaq...          50
# ...

# %%
df.columns
# Out:
# Index(['abstract', 'authors', 'n_citation', 'references', 'title', 'venue',
#        'year', 'id'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# abstract      172467
# authors            2
# n_citation         0
# references    124417
# title              0
# venue         177755
# year               0
# id                 0
# dtype: int64

# %%
df.dtypes
# Out:
# abstract      object
# authors       object
# n_citation     int64
# references    object
# title         object
# venue         object
# year           int64
# id            object
# dtype: object

# %%
df = df.dropna()

# %%
df
# Out:
#                                                  abstract  \
# 0       In this paper, a robust 3D triangular mesh wat...
# 1       We studied an autoassociative neural network w...
# 2       It is well-known that Sturmian sequences are t...
# 3       One of the fundamental challenges of recognizi...
# 4       This paper generalizes previous optimal upper ...
# ...                                                   ...
# 999992  Assume n wireless mobile sensors are initially...
# 999993  Zero-shot Learning (ZSL) can leverage attribut...
# 999994  Abstract The article presents a narrative revi...
# 999997  In this work, a distillation system is designe...
# 999999  The uninorms with continuous underlying t-norm...
#
#                                                   authors  n_citation  \
# 0                  ['S. Ben Jabra', 'Ezzeddine Zagrouba']          50
# 1       ['Joaquín J. Torres', 'Jesús M. Cortés', 'Joaq...          50
# ...

# %%
df.isna().sum()
# Out:
# abstract      0
# authors       0
# n_citation    0
# references    0
# title         0
# venue         0
# year          0
# id            0
# dtype: int64

# %%
df.to_csv('cleaned_dataset_research_paper.csv')
